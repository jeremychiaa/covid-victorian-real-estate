# %%
# this notebook is to come up with some stats and analysis
# in order to determine colleration (if any) with property sales
# before Covid outbreak and during pandemic in Victoria

# %%
import pandas as pd
import numpy as np

# %%
crime_df = pd.read_csv("Resources/crime_data.csv")

# %%
crime_df.tail()
# Out:
#      Unnamed: 0  Year Year ending  \
# 865         865  2011       March
# 866         866  2011       March
# 867         867  2011       March
# 868         868  2011       March
# 869         869  2011       March
#
#                                        Police Region  \
# 865                                        4 Western
# 866  Justice Institutions and Immigration Facilities
# 867  Justice Institutions and Immigration Facilities
# 868                               Unincorporated Vic
# 869                               Unincorporated Vic
#
#                                                Suburb Incidents Recorded  \
# 865                                             Total            49,482
# 866   Justice Institutions and Immigration Facilities               667
# 867                                             Total               667
# 868                                Unincorporated Vic               170
# 869                                             Total               170
#
#     Rate per 100,000 population
# 865                    5,486.4
# 866                         NaN
# 867                         NaN
# 868                         NaN
# 869                         NaN

# %%
covid_df = pd.read_csv("Resources/data-83bcX.csv")

# %%
covid_df.head()
# Out:
#     Date  Alpine  Ararat  Ballarat  Banyule  Bass Coast  Baw Baw  Bayside  \
# 0  01/07       1       5        11       98           4        5       35
# 1  02/07       1       5        11       99           4        5       36
# 2  03/07       1       5        11       99           4        5       36
# 3  04/07       1       5        11       99           4        5       36
# 4  05/07       1       5        11       99           4        5       36
#
#    Benalla  Boroondara  ...  Warrnambool  Wellington  West Wimmera  \
# 0        3          76  ...            5          12             1
# 1        3          76  ...            5          12             1
# 2        3          76  ...            5          12             1
# 3        3          78  ...            5          12             1
# 4        3          78  ...            5          12             1
#
#    Whitehorse  Whittlesea  Wodonga  Wyndham  Yarra  Yarra Ranges  Yarriambiack
# 0          26          65        1       75     42            26             1
# 1          28          67        1       81     44            27             1
# 2          28          71        1       88     46            27             1
# 3          30          78        1      107     47            27             1
# 4          30          82        1      122     49            27             1
#
# [5 rows x 80 columns]
