# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Read into csv file
schools_csv_file = "./Resources/dv279-schoollocations2019.csv"
schools_df = pd.read_csv(schools_csv_file)
schools_df.head()
# Out:
#   Education_Sector  Entity_Type  School_No  \
# 0       Government            1          1
# 1       Government            1          3
# 2       Government            1          4
# 3       Government            1          8
# 4       Government            1         12
#
#                               School_Name School_Type School_Status  \
# 0                 Alberton Primary School     Primary             O
# 1  Allansford and District Primary School     Primary             O
# 2                    Avoca Primary School     Primary             O
# 3                   Avenel Primary School     Primary             O
# 4               Warrandyte Primary School     Primary             O
#
#        Address_Line_1 Address_Line_2 Address_Town Address_State  ...  \
# 0   21 Thomson Street            NaN     Alberton           VIC  ...
# 1        Frank Street            NaN   Allansford           VIC  ...
# 2  118 Barnett Street            NaN        Avoca           VIC  ...
# 3  40 Anderson Street            NaN       Avenel           VIC  ...
# 4  5-11 Forbes Street            NaN   Warrandyte           VIC  ...
#
#    Postal_Address_Line_1 Postal_Address_Line_2 Postal_Town Postal_State  \
# 0      21 Thomson Street                   NaN    ALBERTON          VIC
# 1           Frank Street                   NaN  ALLANSFORD          VIC
# 2             P O Box 12                   NaN       AVOCA          VIC
# 3     40 Anderson Street                   NaN      AVENEL          VIC
# 4     5-11 Forbes Street                   NaN  WARRANDYTE          VIC
#
#   Postal_Postcode  Full_Phone_No LGA_ID         LGA_Name           X  \
# 0            3971   03 5183 2412    681   Wellington (S)  146.666601
# 1            3277   03 5565 1382    673  Warrnambool (C)  142.590393
# 2            3467   03 5465 3176    599     Pyrenees (S)  143.475649
# 3            3664   03 5796 2264    643  Strathbogie (S)  145.234722
# 4            3113   03 9844 3537    421   Manningham (C)  145.213980
#
#            Y
# 0 -38.617713
# 1 -38.386281
# 2 -37.084502
# 3 -36.901368
# 4 -37.742675
#
# [5 rows x 21 columns]

# %%
# Ensuring all schools are in VIC
schools_df["Postal_State"].unique()
# Out:
# array(['VIC'], dtype=object)

# %%
# Drop unwanted columns
to_drop = ["School_Status",
          "Address_Line_1",
          "Address_Line_2",
          "Address_Town",
          "Address_State",
          "Postal_Address_Line_2",
          "Full_Phone_No",
          "Address_Postcode"]

schools_df.drop(columns=to_drop, inplace=True)

# %%
schools_df.head()
# Out:
#   Education_Sector  Entity_Type  School_No  \
# 0       Government            1          1
# 1       Government            1          3
# 2       Government            1          4
# 3       Government            1          8
# 4       Government            1         12
#
#                               School_Name School_Type Postal_Address_Line_1  \
# 0                 Alberton Primary School     Primary     21 Thomson Street
# 1  Allansford and District Primary School     Primary          Frank Street
# 2                    Avoca Primary School     Primary            P O Box 12
# 3                   Avenel Primary School     Primary    40 Anderson Street
# 4               Warrandyte Primary School     Primary    5-11 Forbes Street
#
#   Postal_Town Postal_State  Postal_Postcode  LGA_ID         LGA_Name  \
# 0    ALBERTON          VIC             3971     681   Wellington (S)
# 1  ALLANSFORD          VIC             3277     673  Warrnambool (C)
# 2       AVOCA          VIC             3467     599     Pyrenees (S)
# 3      AVENEL          VIC             3664     643  Strathbogie (S)
# 4  WARRANDYTE          VIC             3113     421   Manningham (C)
#
#             X          Y
# 0  146.666601 -38.617713
# 1  142.590393 -38.386281
# 2  143.475649 -37.084502
# 3  145.234722 -36.901368
# 4  145.213980 -37.742675

# %%
# Store town name and postcode in a dict
suburb_postcode = dict(zip(schools_df["Postal_Town"], schools_df["Postal_Postcode"]))
suburb_postcode
# Out:
# {'ALBERTON': 3971,
#  'ALLANSFORD': 3277,
#  'AVOCA': 3467,
#  'AVENEL': 3664,
#  'WARRANDYTE': 3113,
#  'BELMONT': 3216,
#  'Bacchus Marsh': 3340,
#  'BALLARAT': 3354,
#  'WODONGA': 3689,
#  'Berwick': 3806,
#  'BEAUFORT': 3373,
#  'CHELTENHAM': 3192,
#  'CUDGEE': 3265,
#  'NEWPORT': 3015,
#  'CAVENDISH': 3314,
#  'COLAC': 3250,
#  'CASTLEMAINE': 3450,
#  'CAMPBELLS CREEK': 3451,
#  'CRESWICK': 3363,
#  'CALIFORNIA GULLY': 3556,
#  'ST ANDREWS': 3761,
#  'WARRNAMBOOL': 3280,
#  'DROMANA': 3936,
#  'Westfield, Doncaster': 3108,
#  'ECHUCA': 3564,
#  'ELTHAM': 3095,
#  'EAGLEHAWK': 3556,
#  'ELPHINSTONE': 3448,
#  'HALLAM': 3803,
#  'FLEMINGTON': 3031,
#  'WEST FOOTSCRAY': 3012,
#  'GISBORNE': 3437,
#  'SANDRINGHAM': 3191,
#  'BRIGHT': 3741,
#  'GROVEDALE': 3216,
#  'HAWTHORN': 3122,
#  'HEIDELBERG': 3084,
#  'HAMILTON': 3300,
#  'HEATHCOTE': 3523,
#  'HIGHTON': 3216,
#  'HUNTLY': 3551,
#  'BELLBRAE': 3228,
#  'CHILTERN': 3683,
#  'KYNETON': 3444,
#  'ROMSEY': 3434,
#  'SHELFORD': 3329,
#  'LOCKWOOD SOUTH': 3551,
#  'MARONG': 3515,
#  'MOUNT MACEDON': 3441,
#  'MOUNT CLEAR': 3350,
#  'MELTON': 3337,
#  'FITZROY': 3065,
#  'NEWSTEAD': 3462,
#  'NEWLYN': 3364,
#  'GLEN WAVERLEY': 3150,
#  'NEW GISBORNE': 3438,
#  'BEEAC': 3251,
#  'ESSENDON': 3040,
#  'COBURG': 3058,
#  'PENSHURST': 3289,
#  'MYRNIONG': 3341,
#  'MERNDA': 3754,
#  'PORTLAND': 3305,
#  'STAWELL': 3380,
#  'RUTHERGLEN': 3685,
#  'RIDDELLS CREEK': 3431,
#  'ROKEWOOD': 3330,
#  'GEELONG EAST': 3219,
#  'SALE': 3850,
#  'SKIPTON': 3361,
#  'SOUTH YARRA': 3141,
#  'STRATFORD': 3862,
#  'TARADALE': 3447,
#  'KOROIT': 3282,
#  'TYLDEN': 3444,
#  'THOMASTOWN': 3074,
#  'WANGARATTA': 3676,
#  'WAHGUNYAH': 3687,
#  'WOODEND': 3442,
#  'WOODFORD': 3281,
#  'WERRIBEE': 3030,
#  'Beechworth': 3747,
#  'WALLAN': 3756,
#  'WOOLSTHORPE': 3276,
#  'Yandoit': 3461,
#  'YARRAM': 3971,
#  'LAKE WENDOUREE': 3350,
#  'YEA': 3717,
#  'LANCEFIELD': 3435,
#  'COIMADAI': 3340,
#  'BIRREGURRA': 3242,
#  'CLAYTON': 3168,
#  'MILAWA': 3678,
#  'LOCKWOOD': 3551,
#  'BEALIBA': 3475,
#  'BAIRNSDALE': 3875,
#  'GORDON': 3345,
#  'HEPBURN': 3461,
#  'LARA LAKE': 3212,
#  'ROSEDALE': 3847,
#  'ROCHESTER': 3561,
#  'ARARAT': 3377,
#  'JAMIESON': 3723,
#  'PRESTON': 3072,
#  'OMEO': 3898,
#  'HARRIETVILLE': 3741,
#  'Mordialloc': 3195,
#  'HEALESVILLE': 3777,
#  'LAKE BOLAC': 3351,
#  'TOONGABBIE': 3856,
#  'WAUBRA': 3352,
#  'GREAT WESTERN': 3374,
#  'MAFFRA': 3860,
#  'Broken Creek': 3673,
#  'LAL LAL': 3352,
#  'COBDEN': 3266,
#  'ST LEONARDS': 3223,
#  'Lilydale': 3140,
#  'BENDIGO': 3550,
#  'DARRAWEIT GUIM': 3756,
#  'LINTON': 3360,
#  'INVERMAY': 3352,
#  'MITTA MITTA': 3701,
#  'CAMBERWELL': 3124,
#  'GREENVALE': 3059,
#  'ALEXANDRA': 3714,
#  'BANNOCKBURN': 3331,
#  'DOREEN': 3754,
#  'TALBOT': 3371,
#  'Yarra Glen': 3775,
#  'ELMHURST': 3469,
#  'KANGAROO FLAT': 3555,
#  'Westmeadows': 3049,
#  'SUNBURY': 3429,
#  'DIAMOND CREEK': 3089,
#  'Woodend': 3442,
#  'AXEDALE': 3551,
#  'VERMONT': 3133,
#  'TARNAGULLA': 3551,
#  'BALWYN': 3101,
#  'SCORESBY': 3179,
#  'CARISBROOK': 3464,
#  'WANDIN NORTH': 3139,
#  'Coldstream': 3770,
#  'DARTMOOR': 3304,
#  'MICKLEHAM': 3064,
#  'INGLEWOOD': 3517,
#  'CHEWTON': 3451,
#  'BOLINDA': 3432,
#  'NAPOLEONS': 3352,
#  'KEW': 3101,
#  'HADDON': 3351,
#  'PANMURE': 3265,
#  'SORRENTO': 3943,
#  'ALFREDTON': 3350,
#  'BRIDGEWATER': 3516,
#  'HASTINGS': 3915,
#  'YACKANDANDAH': 3749,
#  'NAGAMBIE': 3608,
#  'HEYFIELD': 3858,
#  'MOORABBIN': 3189,
#  'MANSFIELD': 3724,
#  'Indigo Valley': 3688,
#  'BRIAGOLONG': 3860,
#  'LINDENOW': 3865,
#  'BROADFORD': 3658,
#  'MURCHISON': 3610,
#  'PANTON HILL': 3759,
#  'GLEN PARK': 3352,
#  'CONCONGELLA': 3384,
#  'BRUTHEN': 3885,
#  'SWAN HILL': 3585,
#  'POREPUNKAH': 3740,
#  'LEOPOLD': 3224,
#  'INVERLEIGH': 3321,
#  'GLEN IRIS': 3146,
#  'TRAWALLA': 3373,
#  'BENDIGO DC': 3554,
#  'SEBASTOPOL': 3356,
#  'WOODSIDE': 3874,
#  'NOORAT': 3265,
#  'ALBERT PARK': 3206,
#  'WILLIAMSTOWN': 3016,
#  'RYE': 3941,
#  'QUEENSCLIFF': 3225,
#  'PORTLAND NORTH': 3305,
#  'TIMOR': 3465,
#  'APSLEY': 3319,
#  'STRATHFIELDSAYE': 3551,
#  'Carrum Downs': 3201,
#  'TOOBORAC': 3522,
#  'Bairnsdale': 3875,
#  'Wallan': 3756,
#  'CARLTON NORTH': 3054,
#  'MALDON': 3463,
#  'WOORI YALLOCK': 3139,
#  'Moyston': 3377,
#  'BUNINYONG': 3357,
#  'MARYSVILLE': 3779,
#  'LANGLEY': 3444,
#  'WANDONG': 3758,
#  'COWES': 3922,
#  'BULLARTO': 3461,
#  'LISMORE': 3324,
#  'LOWER PLENTY': 3093,
#  'GOLDEN SQUARE': 3555,
#  'BOLWARRA': 3305,
#  'NAVARRE': 3384,
#  'WARRACKNABEAL': 3393,
#  'MOYHU': 3732,
#  'NATTE YALLOCK': 3465,
#  'CLIFTON HILL': 3068,
#  'CHRISTMAS HILLS': 3775,
#  'TALLANGATTA': 3700,
#  'KIALLA': 3631,
#  'MOUNT ELIZA': 3930,
#  'San Remo': 3925,
#  'DIMBOOLA': 3414,
#  'WHOROULY': 3735,
#  'Merrijig': 3723,
#  'LETHBRIDGE': 3332,
#  'Oxley': 3678,
#  'NORTHCOTE': 3070,
#  'NORTH MELBOURNE': 3051,
#  'DANDENONG': 3175,
#  'MALMSBURY': 3446,
#  'WILLIAMSTOWN NORTH': 3016,
#  'KERANG': 3579,
#  'DROUIN': 3818,
#  'MEREDITH': 3333,
#  'EDI UPPER': 3678,
#  'MOOROOPNA': 3629,
#  'CAIRNLEA': 3023,
#  'BALLAN': 3342,
#  'TATURA': 3616,
#  'TOOLAMBA': 3614,
#  'OSBORNES FLAT': 3691,
#  'FRANKSTON EAST LPO': 3199,
#  'DONALD': 3480,
#  'BEVERIDGE': 3753,
#  'ST KILDA': 3182,
#  'Cape Clear': 3351,
#  'WARBURTON': 3799,
#  'TALLAROOK': 3659,
#  'BARNAWARTHA': 3688,
#  'FITZROY NORTH': 3068,
#  'GEELONG WEST': 3218,
#  'TOORADIN': 3980,
#  'ELMORE': 3558,
#  'DOOKIE': 3646,
#  'BRIGHTON': 3186,
#  'NATIMUK': 3409,
#  'MURTOA': 3390,
#  'Big Hill': 3555,
#  'CLUNES': 3370,
#  'MARNOO': 3387,
#  'BEECHWORTH': 3747,
#  'ARDMONA': 3629,
#  'KILMORE': 3764,
#  'MACARTHUR': 3286,
#  'BARWON HEADS': 3227,
#  'KEILOR': 3036,
#  'DUNOLLY': 3472,
#  'SPRINGHURST': 3682,
#  'DIXONS CREEK': 3775,
#  'TRENTHAM': 3458,
#  'WARRENHEIP': 3352,
#  'MAIDEN GULLY': 3551,
#  'RUPANYUP': 3388,
#  'GOORNONG': 3557,
#  'OAKLEIGH': 3166,
#  'CERES': 3221,
#  'MALVERN': 3144,
#  'DAYLESFORD': 3461,
#  'SWAN REACH': 3903,
#  'AMPHITHEATRE': 3468,
#  'DEANS MARSH': 3235,
#  'DRYSDALE': 3222,
#  'St Arnaud': 3478,
#  'NULLAWARRE': 3268,
#  'MACEDON': 3440,
#  'ARTHURS CREEK': 3099,
#  'Buxton': 3711,
#  'MOONAMBEL': 3478,
#  'BARINGHUP': 3463,
#  'Longford': 3851,
#  'HARKAWAY': 3806,
#  'BALNARRING': 3926,
#  'Londrigan via Wangaratta': 3678,
#  'EUROA': 3666,
#  'PYRAMID HILL': 3575,
#  'SHEPPARTON EAST': 3631,
#  'NICHOLSON': 3882,
#  'KIALLA WEST': 3631,
#  'MINERS REST': 3352,
#  'GLENROWAN': 3675,
#  'DEVENISH': 3726,
#  'UNDERA': 3629,
#  'DEDERANG': 3691,
#  'AXE CREEK, via Strathfieldsaye': 3551,
#  'SILVAN': 3795,
#  'Wendouree': 3355,
#  'LANCASTER': 3620,
#  'RAYWOOD': 3570,
#  'Drummond': 3461,
#  'PUCKAPUNYAL': 3662,
#  'LANDSBOROUGH': 3384,
#  'LYSTERFIELD': 3156,
#  'WINTON': 3673,
#  'MERRIGUM': 3618,
#  'BETHANGA': 3691,
#  'ABBOTSFORD': 3067,
#  'NEWTOWN': 3220,
#  'WINDSOR': 3181,
#  'NARRE WARREN NORTH': 3804,
#  'BUCHAN': 3885,
#  'Anakie': 3213,
#  'MOOLAP': 3221,
#  'Footscray': 3011,
#  'NEWHAM': 3442,
#  'MILL PARK': 3082,
#  'WHITE HILLS': 3550,
#  'Mount Egerton': 3352,
#  'WUNGHNU': 3635,
#  'MAROONA': 3377,
#  'JINDIVICK': 3818,
#  'TALGARNO': 3691,
#  'Bungaree': 3352,
#  'LITTLE RIVER': 3211,
#  'COWWARR': 3857,
#  'SOUTH MORANG': 3752,
#  'PYALONG': 3521,
#  'WINCHELSEA': 3241,
#  'BULN BULN': 3821,
#  'SOLDIERS HILL': 3350,
#  'MORNINGTON': 3931,
#  'BLOWHARD': 3352,
#  'YARRAMBAT': 3091,
#  'THOONA': 3726,
#  'CASTERTON': 3311,
#  'NATHALIA': 3638,
#  'GREENSBOROUGH': 3088,
#  'TEESDALE': 3328,
#  'CRANBOURNE': 3977,
#  'Katamatite': 3649,
#  'BUANGOR': 3375,
#  'LEITCHVILLE': 3567,
#  'WHITTLESEA': 3757,
#  'Nerrina': 3350,
#  'WARRAGUL': 3820,
#  'KANGAROO GROUND': 3097,
#  'TRARALGON SOUTH': 3844,
#  'Coleraine': 3315,
#  'LAKE CHARM': 3581,
#  'RIPPLEBROOK': 3818,
#  'NUMURKAH': 3636,
#  'MOE': 3825,
#  'GEELONG': 3220,
#  'BAYSWATER': 3153,
#  'MINYIP': 3392,
#  'MULGRAVE': 3170,
#  'YARRAGON': 3823,
#  'TYERS': 3844,
#  'TRAFALGAR': 3824,
#  'KINGLAKE': 3763,
#  'ELLINBANK': 3821,
#  'BARANDUDA': 3691,
#  'TUNGAMAH': 3728,
#  'BUNYIP': 3815,
#  'GUNBOWER': 3566,
#  'NAR NAR GOON': 3812,
#  'TOORA': 3962,
#  'MONTROSE': 3765,
#  'KOONDROOK': 3580,
#  'KATUNGA': 3640,
#  'Magpie': 3352,
#  'TAWONGA': 3697,
#  'Narracan': 3824,
#  'ESKDALE': 3701,
#  'DARNUM': 3822,
#  'MOOROODUC': 3933,
#  'THE BASIN': 3154,
#  'PAYNESVILLE': 3880,
#  'EPSOM': 3551,
#  'KENSINGTON': 3031,
#  'HAZELWOOD NORTH': 3840,
#  'MIRBOO NORTH': 3871,
#  'YINNAR': 3869,
#  'NEERIM SOUTH': 3831,
#  'IVANHOE': 3079,
#  'PORTARLINGTON': 3223,
#  'THE PATCH': 3792,
#  'LABERTOUCHE': 3816,
#  'DIGGERS REST': 3427,
#  'LONGWARRY': 3816,
#  'Gembrook': 3783,
#  'WURRUK': 3850,
#  'WILLOW GROVE': 3825,
#  'HODDLES CREEK': 3139,
#  'BEACONSFIELD UPPER': 3808,
#  'CONGUPNA': 3633,
#  'REDESDALE': 3444,
#  'MALVERN EAST': 3145,
#  'Launching Place': 3139,
#  'CARLTON': 3053,
#  'ASCOT VALE': 3032,
#  'BOOLARRA': 3870,
#  'ROSEBUD': 3939,
#  'KOO WEE RUP': 3981,
#  'ARMADALE': 3143,
#  'MOUNT MARTHA': 3934,
#  'SOMERVILLE': 3912,
#  'WILLAURA': 3379,
#  'LAKES ENTRANCE': 3909,
#  'Myrrhee': 3732,
#  'LONGWOOD': 3665,
#  'FORREST': 3236,
#  'FAIRFIELD': 3078,
#  'NILMA': 3821,
#  'GARFIELD': 3814,
#  'YINNAR SOUTH': 3869,
#  'OFFICER': 3809,
#  'BRUNSWICK EAST': 3057,
#  'ORBOST': 3888,
#  'INVERLOCH': 3996,
#  'SURREY HILLS': 3127,
#  'SOUTH MELBOURNE': 3205,
#  'STRATHMERTON': 3641,
#  'LAHARUM': 3401,
#  'WALWA': 3709,
#  'MIDDLE PARK': 3206,
#  'SEVILLE': 3139,
#  'YARRAVILLE': 3013,
#  'MORELAND': 3058,
#  'TANJIL SOUTH': 3825,
#  'POMONAL': 3381,
#  'GLENGARRY': 3854,
#  'CARNEGIE': 3163,
#  'LANG LANG': 3984,
#  'CROYDON': 3136,
#  'MOONEE PONDS': 3039,
#  'MITCHAM': 3132,
#  'LOCH': 3945,
#  'MILDURA': 3500,
#  'BLACKBURN': 3130,
#  'Newmerella': 3888,
#  'PORT MELBOURNE': 3207,
#  'HAWTHORN EAST': 3123,
#  'MENTONE': 3194,
#  'COLDSTREAM': 3770,
#  'RESEARCH': 3095,
#  'PEARCEDALE': 3912,
#  'Lindenow South': 3875,
#  'THORPDALE': 3835,
#  'ST ALBANS': 3021,
#  'LEONGATHA': 3953,
#  'JEPARIT': 3423,
#  'TOORAK': 3142,
#  'BAXTER': 3911,
#  'Fish Creek': 3959,
#  'BEACONSFIELD': 3807,
#  'METUNG': 3904,
#  'Newhaven': 3925,
#  'HALLS GAP': 3381,
#  'TALLYGAROOPNA': 3634,
#  'BENTLEIGH': 3204,
#  'KORUMBURRA': 3950,
#  'CRIB POINT': 3919,
#  'PASCOE VALE': 3044,
#  'FLOWERDALE': 3717,
#  'OCEAN GROVE': 3226,
#  'BEULAH': 3395,
#  'SUNSHINE': 3020,
#  'TYABB': 3913,
#  'THORNBURY': 3071,
#  'HUON': 3695,
#  'Kew East': 3102,
#  'NICHOLS POINT': 3501,
#  'IRYMPLE': 3498,
#  'EAGLE POINT': 3878,
#  'Yarra Junction': 3797,
#  'SASSAFRAS': 3787,
#  'Ferny Creek': 3786,
#  'TOOLANGI': 3777,
#  'WONGA PARK': 3115,
#  'KINGLAKE WEST': 3757,
#  'MONBULK': 3793,
#  'LAKE BOGA': 3584,
#  'CHUM CREEK': 3777,
#  'KALORAMA': 3766,
#  'NULLAWIL': 3529,
#  'KINGLAKE CENTRAL': 3757,
#  'POINT LONSDALE': 3225,
#  'CLARINDA': 3169,
#  'CHELSEA HEIGHTS': 3196,
#  'WALLINGTON': 3222,
#  'TECOMA': 3160,
#  'TORQUAY': 3228,
#  'NOORINBEE': 3890,
#  'Emerald': 3782,
#  'SEAFORD': 3198,
#  'NYORA': 3987,
#  'EXFORD': 3338,
#  'ULTIMA': 3544,
#  'MOUNT WAVERLEY': 3149,
#  'MARLO': 3888,
#  'MURRUMBEENA': 3163,
#  'YARRA JUNCTION': 3797,
#  'KOORLONG': 3501,
#  'Warranwood': 3134,
#  'WILLOWMAVIN': 3764,
#  'Olinda': 3788,
#  'CARLISLE RIVER': 3239,
#  'STRATHDALE': 3550,
#  'MALLACOOTA': 3892,
#  'LANGWARRIN': 3910,
#  'Cockatoo': 3781,
#  'UPWEY': 3158,
#  'SYDENHAM': 3037,
#  'CANTERBURY': 3126,
#  'CABARITA': 3505,
#  'TRARALGON': 3844,
#  'BRUNSWICK WEST': 3055,
#  'FAWKNER': 3060,
#  'ALPHINGTON': 3078,
#  'BONA VISTA': 3820,
#  'CARRUM DOWNS': 3201,
#  'BUNDOORA': 3083,
#  'Macclesfield': 3782,
#  'BLACK ROCK': 3193,
#  'MOUNT EVELYN': 3796,
#  'KILSYTH': 3137,
#  'WONTHAGGI': 3995,
#  'Spotswood': 3015,
#  'CLYDE': 3978,
#  'NOBLE PARK': 3174,
#  'DEEPDENE': 3103,
#  'Clifton Creek': 3875,
#  'CARDINIA': 3978,
#  'GRAHAMVALE': 3631,
#  'GLEN HUNTLY': 3163,
#  'NANNEELLA': 3561,
#  'WANTIRNA': 3152,
#  'MELTON SOUTH': 3338,
#  'CHELSEA': 3196,
#  'NOWA NOWA': 3887,
#  'Hampton': 3188,
#  'St Kilda Rd Central, MELBOURNE': 8008,
#  'BALLIANG EAST': 3340,
#  'EDITHVALE': 3196,
#  'ORRVALE': 3631,
#  'UNDERBOOL': 3509,
#  'CAULFIELD NORTH': 3161,
#  'BURWOOD': 3125,
#  'MURRABIT': 3579,
#  'BRIGHTON EAST': 3187,
#  'Cromer': 3193,
#  'Dookie Campus': 3647,
#  'CANN RIVER': 3890,
#  'ALTONA': 3018,
#  'DEVON MEADOWS': 3977,
#  'UPPER FERNTREE GULLY': 3156,
#  'EILDON': 3713,
#  'BITTERN': 3918,
#  'COLBINABBIN': 3559,
#  'STANHOPE': 3623,
#  'HURSTBRIDGE': 3099,
#  'ELWOOD': 3184,
#  'MONT ALBERT': 3127,
#  'DHURRINGILE': 3610,
#  'Strathewen': 3099,
#  'DON VALLEY': 3139,
#  'RESERVOIR': 3073,
#  'YALLOURN NORTH': 3825,
#  'GIRGARRE': 3624,
#  'YAAPEET': 3424,
#  'GLADYSDALE': 3797,
#  'Moonee Ponds': 3039,
#  'Kallista': 3791,
#  'Essendon North': 3041,
#  'Ascot Vale': 3032,
#  'RED CLIFFS': 3496,
#  'HAMPTON PARK': 3976,
#  'Colac': 3250,
#  'ST KILDA EAST': 3183,
#  'NOOJEE': 3833,
#  'MONTMORENCY': 3094,
#  'MORIAC': 3240,
#  'RINGWOOD NORTH': 3134,
#  'Pascoe Vale': 3044,
#  'POINT COOK': 3030,
#  'AIRLY': 3851,
#  'PARKDALE': 3195,
#  'HUGHESDALE': 3166,
#  'Aspendale': 3195,
#  'ELTHAM NORTH': 3095,
#  'Essendon': 3040,
#  'MANIFOLD HEIGHTS': 3218,
#  'NUNGURNER': 3909,
#  'DINGLEY VILLAGE': 3172,
#  'CARDROSS': 3496,
#  'ALBION': 3020,
#  'LEMNOS': 3631,
#  'TARWIN LOWER': 3956,
#  'CAULFIELD SOUTH': 3162,
#  'ASHBURTON': 3147,
#  'SEASPRAY': 3851,
#  'ANGLESEA': 3230,
#  'BRIAR HILL': 3088,
#  'ZEERUST': 3634,
#  'ORMOND': 3204,
#  'CLAYTON SOUTH': 3169,
#  'IVANHOE EAST': 3079,
#  'COBAINS': 3851,
#  'MILDURA SOUTH': 3501,
#  'KATANDRA WEST': 3634,
#  'NARRE WARREN': 3805,
#  'SOMERS': 3927,
#  'Pascoe Vale South': 3044,
#  'ROSANNA': 3084,
#  'WANTIRNA SOUTH': 3152,
#  'STRATHMORE': 3041,
#  'BALWYN NORTH': 3104,
#  'MOUNT BEAUTY': 3699,
#  'East Coburg': 3058,
#  'NEWBOROUGH': 3825,
#  'SHEPPARTON': 3630,
#  'HAMLYN HEIGHTS': 3215,
#  'KARINGAL CENTRE': 3199,
#  'Selby': 3159,
#  'BALLARAT NORTH': 3350,
#  'BANDIANA MILPO': 3694,
#  'HORSHAM': 3402,
#  'RINGWOOD EAST': 3135,
#  'LALOR': 3075,
#  'BENTLEIGH EAST': 3165,
#  'BLACKBURN NORTH': 3130,
#  'OAKLEIGH SOUTH': 3167,
#  'BOX HILL NORTH': 3129,
#  'FERNTREE GULLY': 3156,
#  'Oak Park': 3046,
#  'Bendigo DC': 3554,
#  'SUNSHINE NORTH': 3020,
#  'CRANBOURNE SOUTH': 3977,
#  'LAKE GARDENS': 3355,
#  'EAST PRESTON': 3072,
#  'NORTH GEELONG': 3215,
#  'CRAIGIEBURN': 3064,
#  'FRANKSTON': 3199,
#  'BRAYBROOK': 3019,
#  'BONBEACH': 3196,
#  'SPRINGVALE': 3171,
#  'BEAUMARIS': 3193,
#  'BRENTFORD SQUARE': 3131,
#  'GLENROY': 3046,
#  'AVONDALE HEIGHTS': 3034,
#  'DONCASTER EAST': 3109,
#  'KERRIMUIR': 3129,
#  'HEATHMONT': 3135,
#  'Mount Waverley': 3149,
#  'East Bentleigh': 3165,
#  'WATSONIA': 3087,
#  'Parkdale': 3195,
#  'KINGSBURY': 3083,
#  'ARDEER': 3022,
#  'TULLAMARINE': 3043,
#  'PARK ORCHARDS': 3114,
#  'Blackburn': 3130,
#  'Bell Post Hill': 3215,
#  'DONVALE': 3111,
#  'Pinewood': 3149,
#  'DALLAS': 3047,
#  'KEILOR EAST': 3033,
#  'BURNT BRIDGE': 3136,
#  'FOREST HILL': 3131,
#  'LARA': 3212,
#  'RINGWOOD': 3134,
#  'VIEWBANK': 3084,
#  'SIMPSON': 3266,
#  'Invergordon': 3636,
#  'MOUNTAIN GATE': 3156,
#  'BORONIA': 3155,
#  'Croydon': 3136,
#  'KARINGAL': 3199,
#  'Moorabbin': 3189,
#  'ALTONA NORTH': 3025,
#  'Burwood East': 3151,
#  'WENDOUREE': 3355,
#  'MOOROOLBARK': 3138,
#  'Pines Forest': 3200,
#  'Kerang': 3579,
#  'Broadmeadows': 3047,
#  'GEELONG NORTH': 3215,
#  'CHURCHILL': 3842,
#  'MORWELL': 3841,
#  'BULLEEN': 3105,
#  'WATSONIA NORTH': 3087,
#  'KNOXFIELD': 3180,
#  'DONCASTER': 3108,
#  'FRANKSTON SOUTH': 3199,
#  'ROWVILLE': 3178,
#  'HOPPERS CROSSING': 3029,
#  'TEMPLESTOWE LOWER': 3107,
#  'Karingal Centre P.O.,FRANKSTON': 3199,
#  'Sunbury': 3429,
#  'GLADSTONE PARK': 3043,
#  'Mooroolbark': 3138,
#  'VERMONT SOUTH': 3133,
#  'DEER PARK': 3023,
#  'CAMPBELLFIELD': 3061,
#  'Wheelers Hill': 3150,
#  'Belvedere Park PO Seaford': 3198,
#  'RICHMOND': 3121,
#  'LILYDALE': 3140,
#  'SUNSHINE WEST': 3020,
#  'Falls Creek': 3699,
#  'DANDENONG NORTH': 3175,
#  'Melton South': 3338,
#  'WHEELERS HILL': 3150,
#  'ASHWOOD': 3147,
#  'Dallas': 3047,
#  'Vermont South': 3133,
#  'NOBLE PARK NORTH': 3174,
#  'WHITTINGTON': 3219,
#  'TEMPLESTOWE': 3106,
#  'CAPEL SOUND': 3940,
#  'ENDEAVOUR HILLS': 3802,
#  'WEST WODONGA': 3690,
#  'ASPENDALE': 3195,
#  'Bellfield': 3081,
#  'COBRAM': 3644,
#  'BRANDON PARK': 3150,
#  'HOPPERS CROSSING DC': 3029,
#  'Altona Meadows': 3028,
#  'Sale': 3850,
#  'ALBANVALE': 3021,
#  'Roxburgh Park': 3064,
#  'PATTERSON LAKES': 3197,
#  'Chirnside Park': 3116,
#  'CORINELLA': 3984,
#  'BACCHUS MARSH': 3340,
#  'Redan': 3350,
#  'MELTON WEST': 3337,
#  'BERWICK': 3806,
#  'Laverton': 3028,
#  'Reservoir': 3073,
#  'BURWOOD EAST': 3151,
#  'MEADOW HEIGHTS': 3048,
#  'LOCH SPORT': 3851,
#  'Mount Evelyn': 3796,
#  'Moorabbin East': 3189,
#  'CROYDON HILLS': 3136,
#  'Taylors Lakes': 3038,
#  'BROADMEADOWS': 3047,
#  'KINGSVILLE': 3012,
#  'BLACKBURN SOUTH': 3130,
#  'EPPING': 3076,
#  'ALTONA MEADOWS': 3028,
#  'DELAHEY': 3037,
#  'ASPENDALE GARDENS': 3195,
#  'KEILOR DOWNS': 3038,
#  'SEABROOK': 3028,
#  'Werribee': 3030,
#  'VIOLET TOWN': 3669,
#  'PAKENHAM': 3810,
#  'CRANBOURNE NORTH': 3977,
#  'DERRINALLUM': 3325,
#  'MORTLAKE': 3272,
#  'BRANXHOLME': 3302,
#  'MOUNT DUNEED': 3217,
#  'GRASMERE': 3281,
#  'NARRAWONG': 3285,
#  'BALLARAT MAIL CENTRE': 3354,
#  'TEMPY': 3489,
#  'RAWSON': 3825,
#  'Bundalaguah': 3851,
#  'LARDNER': 3821,
#  'NAYOOK': 3832,
#  'NAMBROK': 3847,
#  'WELSHPOOL': 3966,
#  'WHITFIELD': 3733,
#  'GRETA SOUTH': 3675,
#  'Everton': 3678,
#  'WAAIA': 3637,
#  'NANGILOC': 3494,
#  'SEA LAKE': 3533,
#  'HARCOURT': 3453,
#  'BEVERFORD': 3590,
#  'NIDDRIE': 3042,
#  'TOOLERN VALE': 3337,
#  'BOX HILL SOUTH': 3128,
#  'MEENIYAN': 3956,
#  'BAYLES': 3981,
#  'DALYSTON': 3992,
#  'WAVERLEY GARDENS': 3170,
#  'OAKLEIGH EAST': 3166,
#  'Boronia': 3155,
#  'EDENHOPE': 3318,
#  'MURRAYVILLE': 3512,
#  'HAWKESDALE': 3287,
#  'YALLAMBIE': 3085,
#  'WOORINEN SOUTH': 3588,
#  'SMYTHESDALE': 3351,
#  'GORMANDALE': 3873,
#  'SOMERTON': 3062,
#  'NEWCOMB': 3219,
#  'NYAH WEST': 3595,
#  'NARRE WARREN SOUTH': 3805,
#  'CRANBOURNE EAST': 3977,
#  'Heathmont': 3135,
#  'HILLSIDE': 3037,
#  'ROXBURGH PARK': 3064,
#  'Point Cook': 3030,
#  'LYNBROOK': 3975,
#  'Doreen': 3754,
#  'Tarneit': 3029,
#  'Caroline Springs': 3023,
#  'Epping': 3076,
#  'Truganina': 3029,
#  'Burnside': 3023,
#  'Narre Warren South': 3805,
#  'Officer': 3809,
#  'Pakenham': 3810,
#  'Cranbourne': 3977,
#  'Blackburn South': 3130,
#  'Deer Park': 3023,
#  'Echuca': 3564,
#  'Cranbourne East': 3977,
#  'Lyndhurst': 3975,
#  'Craigieburn': 3064,
#  'Mernda': 3754,
#  'Sunshine': 3020,
#  'Blackburn North': 3130,
#  'Golden Square': 3555,
#  'Lalor': 3075,
#  'Keysborough': 3173,
#  'Springvale South': 3172,
#  'Dandenong North': 3175,
#  'SPRINGVALE SOUTH': 3172,
#  'Springvale': 3171,
#  'Keilor Downs': 3038,
#  'Nth Bendigo': 3550,
#  'Glenroy': 3046,
#  'Horsham': 3402,
#  'Wyndham Vale': 3024,
#  'Jacana': 3047,
#  'Torquay': 3228,
#  'Melton West': 3337,
#  'Clyde North': 3978,
#  'Southbank': 3006,
#  'Cranbourne West': 3977,
#  'Albert Park': 3206,
#  'Armstrong Creek': 3217,
#  'Geelong West': 3218,
#  'Aireys Inlet': 3231,
#  'Morwell': 3840,
#  'APOLLO BAY': 3233,
#  'BOISDALE': 3860,
#  'COHUNA': 3568,
#  'DUNKELD': 3294,
#  'DINGEE': 3571,
#  'FOSTER': 3960,
#  'GOROKE': 3412,
#  'HEYWOOD': 3304,
#  'TANGAMBALANGA': 3691,
#  'LAVERS HILL': 3238,
#  'LOCKINGTON': 3563,
#  'MANANGATANG': 3546,
#  'TERANG': 3264,
#  'MERINO': 3310,
#  'RUSHWORTH': 3612,
#  'MACLEOD': 3085,
#  'POOWONG': 3988,
#  'PORT FAIRY': 3284,
#  'RED HILL': 3937,
#  'TONGALA': 3621,
#  'WERRIMULL': 3496,
#  'CAMPERDOWN': 3260,
#  'TIMBOON': 3268,
#  'WEDDERBURN': 3518,
#  'MONT ALBERT NORTH': 3129,
#  'Wollert': 3750,
#  'NORTHLAND': 3072,
#  'SOUTHBANK': 3006,
#  'Warrnambool': 3280,
#  'Hawthorn East': 3123,
#  'Beaufort': 3373,
#  'Beaumaris': 3193,
#  'BOX HILL': 3128,
#  'Strathdale': 3550,
#  'FOOTSCRAY': 3011,
#  'EAST GEELONG': 3219,
#  'KEW EAST': 3102,
#  'KYABRAM': 3620,
#  'Lorne P-12 College': 3232,
#  'MARIBYRNONG': 3032,
#  'MORDIALLOC': 3195,
#  'MCKINNON': 3204,
#  'MELBOURNE': 3004,
#  'OUYEN': 3490,
#  'OAK PARK': 3046,
#  'Windsor': 3181,
#  'Preston': 3072,
#  'PRINCES HILL': 3054,
#  'Rainbow': 3424,
#  'Richmond': 3121,
#  'ROBINVALE': 3549,
#  'ST ARNAUD': 3478,
#  'BRUNSWICK': 3056,
#  'PARKVILLE': 3052,
#  'Somerton BC Somerton': 3062,
#  'Vermont': 3133,
#  'Warrandyte': 3113,
#  'Ballarat East': 3354,
#  'CAULFIELD EAST': 3145,
#  'EMERALD': 3782,
#  'Morwell BC': 3841,
#  'COLLINGWOOD': 3066,
#  'Fraser Rise': 3336,
#  'TAYLORS LAKES': 3038,
#  'Thornbury': 3071,
#  'Glen Waverley': 3150,
#  'FRANKSTON NORTH': 3200,
#  'CHARLTON': 3525,
#  'WYCHEPROOF': 3527,
#  'BIRCHIP': 3483,
#  'NHILL': 3418,
#  'ROBINSON': 3019,
#  'KANIVA': 3419,
#  'CORRYONG': 3707,
#  'Maryborough': 3465,
#  'South Morang': 3752,
#  'Coburg': 3058,
#  'Wodonga': 3689,
#  'Monash University': 3800,
#  'Altona': 3018,
#  'Wonthaggi': 3995,
#  'Hallam': 3803,
#  'Endeavour Hills': 3802,
#  'Balmoral': 3407,
#  'Myrtleford': 3736,
#  'Somerville': 3912,
#  'Boort': 3537,
#  'Yarrawonga': 3730,
#  'Seymour': 3661,
#  'Merbein': 3505,
#  'Macleod West': 3085,
#  'St. Albans': 3021,
#  'Swifts Creek': 3896,
#  'Fawkner': 3060,
#  'Sebastopol': 3356,
#  'CORIO': 3214,
#  'Hopetoun': 3396,
#  'DOVETON': 3177,
#  'Benalla': 3672,
#  'Parkville': 3052,
#  'WEST MELBOURNE': 3003,
#  'BALLARAT WEST': 3350,
#  'BALLARAT EAST': 3350,
#  'ELSTERNWICK': 3185,
#  'MARYBOROUGH': 3465,
#  'REDAN': 3350,
#  'SEYMOUR': 3660,
#  'TARRINGTON': 3301,
#  'BENALLA': 3672,
#  'DUNNSTOWN': 3352,
#  'YARRAWONGA': 3730,
#  'ECHUCA WEST': 3564,
#  'PORTLAND SOUTH': 3305,
#  'COLERAINE': 3315,
#  'QUARRY HILL': 3550,
#  'BRUNSWICK NORTH': 3056,
#  'MT ELIZA': 3930,
#  'CORAGULAC': 3249,
#  'DENNINGTON': 3280,
#  'CAULFIELD': 3161,
#  'PRAHRAN EAST': 3181,
#  'MYRTLEFORD': 3737,
#  'KEYSBOROUGH': 3173,
#  'DEEPDENE/BALWYN': 3103,
#  'CAMBERWELL EAST': 3124,
#  'HAMPTON': 3188,
#  'MERBEIN': 3505,
#  'PRESTON WEST': 3072,
#  'PRESTON EAST': 3073,
#  'COBURG EAST': 3058,
#  'CLARKES HILL': 3352,
#  'CHADSTONE': 3148,
#  'IVANHOE NORTH': 3079,
#  'HIGHETT': 3190,
#  'NUNAWADING': 3131,
#  'THORNBURY EAST': 3071,
#  'HEIDELBERG WEST': 3081,
#  'SPOTSWOOD': 3015,
#  'HOPETOUN': 3396,
#  'HERNE HILL': 3218,
#  'KENNINGTON': 3550,
#  'SHEPPARTON SOUTH': 3630,
#  'MORWELL EAST': 3840,
#  'RESERVOIR EAST': 3073,
#  ...}

# %%
# Split LGA Name
schools_df["LGA_Name"] = schools_df.LGA_Name.apply(lambda x: pd.Series(str(x).split(" ")))

# %%
schools_df.head()
# Out:
#   Education_Sector  Entity_Type  School_No  \
# 0       Government            1          1
# 1       Government            1          3
# 2       Government            1          4
# 3       Government            1          8
# 4       Government            1         12
#
#                               School_Name School_Type Postal_Address_Line_1  \
# 0                 Alberton Primary School     Primary     21 Thomson Street
# 1  Allansford and District Primary School     Primary          Frank Street
# 2                    Avoca Primary School     Primary            P O Box 12
# 3                   Avenel Primary School     Primary    40 Anderson Street
# 4               Warrandyte Primary School     Primary    5-11 Forbes Street
#
#   Postal_Town Postal_State  Postal_Postcode  LGA_ID     LGA_Name           X  \
# 0    ALBERTON          VIC             3971     681   Wellington  146.666601
# 1  ALLANSFORD          VIC             3277     673  Warrnambool  142.590393
# 2       AVOCA          VIC             3467     599     Pyrenees  143.475649
# 3      AVENEL          VIC             3664     643  Strathbogie  145.234722
# 4  WARRANDYTE          VIC             3113     421   Manningham  145.213980
#
#            Y
# 0 -38.617713
# 1 -38.386281
# 2 -37.084502
# 3 -36.901368
# 4 -37.742675

# %%
# Sort suburbs into metropolitan and regional
